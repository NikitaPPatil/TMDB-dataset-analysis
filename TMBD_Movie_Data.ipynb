# %%
# importing lib.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading data and showing its first 5 lines
df = pd.read_csv('C:/Users/nikip/OneDrive/Desktop/Projects/TMDB/tmdb-movies.csv')
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
# printing dataframe columns' info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
# taking a look at number of unique values
df.nunique()
# Out:
# id                      10865
# imdb_id                 10855
# popularity              10814
# budget                    557
# revenue                  4702
# original_title          10571
# cast                    10719
# homepage                 2896
# director                 5067
# tagline                  7997
# keywords                 8804
# overview                10847
# runtime                   247
# genres                   2039
# production_companies     7445
# release_date             5909
# vote_count               1289
# vote_average               72
# release_year               56
# budget_adj               2614
# revenue_adj              4840
# dtype: int64

# %%
# closer look at the vote_average values
df.vote_average
# Out:
# 0        6.5
# 1        7.1
# 2        6.3
# 3        7.5
# 4        7.3
#         ...
# 10861    7.4
# 10862    5.7
# 10863    6.5
# 10864    5.4
# 10865    1.5
# Name: vote_average, Length: 10866, dtype: float64

# %%
# calculating duplicated values 
df.duplicated().sum()
# Out:
# 1

# %%
# dropping duplicares and validating the excution
df.drop_duplicates(inplace = True)
df.duplicated().any()
# Out:
# False

# %%
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
# dropping unuseful columns
df.drop(['id', 'imdb_id', 'homepage', 'revenue_adj', 'budget_adj', 'tagline', 'cast', 'overview', 'keywords', 'production_companies', 'director', 'release_date'], axis = 1, inplace = True)

# %%
# check for data frame shape
df.shape
# Out:
# (10865, 9)

# %%
df.isnull().sum()
# Out:
# popularity         0
# budget             0
# revenue            0
# original_title     0
# runtime            0
# genres            23
# vote_count         0
# vote_average       0
# release_year       0
# dtype: int64

# %%
# dropping NaNs ans confirming excution
df.dropna(inplace = True)
df.isnull().any().sum()
# Out:
# 0

# %%
# split values in the hyprid dataframe
df['genres'] = df['genres'].apply(lambda x: x.split("|")[0])
df.head()
# Out:
#    popularity     budget     revenue                original_title  runtime  \
# 0   32.985763  150000000  1513528810                Jurassic World      124
# 1   28.419936  150000000   378436354            Mad Max: Fury Road      120
# 2   13.112507  110000000   295238201                     Insurgent      119
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens      136
# 4    9.335014  190000000  1506249360                     Furious 7      137
#
#       genres  vote_count  vote_average  release_year
# 0     Action        5562           6.5          2015
# 1     Action        6185           7.1          2015
# 2  Adventure        2480           6.3          2015
# 3     Action        5292           7.5          2015
# 4     Action        2947           7.3          2015

# %%
# adding new column for movie profit (revenue - budget)
df['profit'] = df.revenue - df.budget
df.head()
# Out:
#    popularity     budget     revenue                original_title  runtime  \
# 0   32.985763  150000000  1513528810                Jurassic World      124
# 1   28.419936  150000000   378436354            Mad Max: Fury Road      120
# 2   13.112507  110000000   295238201                     Insurgent      119
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens      136
# 4    9.335014  190000000  1506249360                     Furious 7      137
#
#       genres  vote_count  vote_average  release_year      profit
# 0     Action        5562           6.5          2015  1363528810
# 1     Action        6185           7.1          2015   228436354
# 2  Adventure        2480           6.3          2015   185238201
# 3     Action        5292           7.5          2015  1868178225
# 4     Action        2947           7.3          2015  1316249360

# %%
 def catigorize_col (df, col, labels):
    """
    catigorizes a certain column based on its quartiles
   
    Args:
        (df)     df   - dataframe we are proccesing
        (col)    str  - to be catigorized column's name 
        (labels) list - list of labels from min to max
    
    Returns:
        (df)     df   - dataframe with the categorized col
    """
    
    # setting the edges to cut the column accordingly
    edges = [df[col].describe()['min'],
             df[col].describe()['25%'],
             df[col].describe()['50%'],
             df[col].describe()['75%'],
             df[col].describe()['max']]
    
    df[col] = pd.cut(df[col], edges, labels = labels, duplicates='drop')
    return df

# %%
# define labels for these edges
labels = ['not_popular', 'below_avg', 'average', 'popular']
catigorize_col(df, 'vote_average', labels)

df['vote_average'].unique()
# Out:
# ['average', 'popular', 'below_avg', 'not_popular', NaN]
# Categories (4, object): ['not_popular' < 'below_avg' < 'average' < 'popular']

# %%
# dropping nans and confirming
df.dropna(inplace = True)
df.isnull().sum()
# Out:
# popularity        0
# budget            0
# revenue           0
# original_title    0
# runtime           0
# genres            0
# vote_count        0
# vote_average      0
# release_year      0
# profit            0
# dtype: int64

# %%
# define labels for these edges
labels = ['low', 'average', 'high']
catigorize_col(df, 'profit', labels)

df['profit'].unique()
# Out:
# ['high', 'average', 'low', NaN]
# Categories (3, object): ['low' < 'average' < 'high']

# %%
df.profit.isnull().sum()
# Out:
# 1

# %%
# dropping NaNs in profic column and confirming
df.dropna(inplace = True)
df.isnull().sum()
# Out:
# popularity        0
# budget            0
# revenue           0
# original_title    0
# runtime           0
# genres            0
# vote_count        0
# vote_average      0
# release_year      0
# profit            0
# dtype: int64

# %%
df.head()
# Out:
#    popularity     budget     revenue                original_title  runtime  \
# 0   32.985763  150000000  1513528810                Jurassic World      124
# 1   28.419936  150000000   378436354            Mad Max: Fury Road      120
# 2   13.112507  110000000   295238201                     Insurgent      119
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens      136
# 4    9.335014  190000000  1506249360                     Furious 7      137
#
#       genres  vote_count vote_average  release_year profit
# 0     Action        5562      average          2015   high
# 1     Action        6185      popular          2015   high
# 2  Adventure        2480      average          2015   high
# 3     Action        5292      popular          2015   high
# 4     Action        2947      popular          2015   high

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10839 entries, 0 to 10864
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   popularity      10839 non-null  float64
#  1   budget          10839 non-null  int64
#  2   revenue         10839 non-null  int64
#  3   original_title  10839 non-null  object
#  4   runtime         10839 non-null  int64
#  5   genres          10839 non-null  object
#  6   vote_count      10839 non-null  int64
#  7   vote_average    10839 non-null  category
#  8   release_year    10839 non-null  int64
#  9   profit          10839 non-null  category
# dtypes: category(2), float64(1), int64(5), object(2)
# memory usage: 783.6+ KB

# %% [markdown]
# Q1: Do movies with high popularity achive high revenvue?

# %%
# get median of popularity to compare with
df['popularity'].mean()
# Out:
# 0.6476021913460651

# %%
# split popular movies into two groups around the median
less_popular = df.query('popularity <= 0.647')
more_popular = df.query('popularity >  0.647')
# get mean quality revenue for the less and more popularity groups
print(less_popular.revenue.mean(), more_popular.revenue.mean())
# Out:
# 7689823.871224779 121933819.08567691

# %% [markdown]
# Q2: What are the most filmed genres in this whole dataset?

# %%
# visualising genres distribution
plt.figure(figsize=(8,5))
df['genres'].value_counts().plot(kind="bar")
plt.title("The most filmed genres", fontsize=(10))
plt.xlabel("genres", fontsize=10)
plt.ylabel("Count",fontsize=10)
plt.show()

# %%
df['genres'].describe()
# Out:
# count     10839
# unique       20
# top       Drama
# freq       2453
# Name: genres, dtype: object

# %% [markdown]
# Q3: Is there a correlation between a movie budget and its revenue?

# %%
# plotting budget against revenue
plt.scatter(df['budget'],df['revenue']);
plt.title("movie budget against its revenue");
plt.xlabel('budget', fontsize=10);
plt.ylabel('revenue',fontsize=10);

# %% [markdown]
# Q4: What is the trend of movie releases over the years?

# %%
# Plotting the number of movies released per year
plt.figure(figsize=(10,6))
df['release_year'].value_counts().sort_index().plot(kind='line')
plt.title("Number of Movies Released Over the Years", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Number of Movies", fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# Q5: What is the distribution of movie runtimes?

# %%
# Plotting the distribution of movie runtimes
plt.figure(figsize=(8,6))
sns.histplot(df['runtime'], bins=30, kde=True)
plt.title('Distribution of Movie Runtimes', fontsize=14)
plt.xlabel('Runtime (minutes)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(True)
plt.show()

# Summary statistics for runtime
df['runtime'].describe()
# Out:
# count    10839.000000
# mean       102.142725
# std         31.297385
# min          0.000000
# 25%         90.000000
# 50%         99.000000
# 75%        111.000000
# max        900.000000
# Name: runtime, dtype: float64

# %% [markdown]
# Q6: What is the relationship between vote count and popularity?

# %%
# Plotting vote count against popularity
plt.figure(figsize=(8,6))
plt.scatter(df['vote_count'], df['popularity'], alpha=0.5)
plt.title("Vote Count vs Popularity", fontsize=14)
plt.xlabel("Vote Count", fontsize=12)
plt.ylabel("Popularity", fontsize=12)
plt.grid(True)
plt.show()

# Correlation between vote count and popularity
df[['vote_count', 'popularity']].corr()
# Out:
#             vote_count  popularity
# vote_count    1.000000    0.800781
# popularity    0.800781    1.000000

# %% [markdown]
# Q7: Which movies had the highest profit margins?

# %%
# Calculating profit margin as (revenue - budget) / budget
df['profit_margin'] = (df['revenue'] - df['budget']) / df['budget']

# Sorting by profit margin and displaying the top 5 movies
top_profit_margin = df[['original_title', 'profit_margin']].sort_values(by='profit_margin', ascending=False).head(5)
top_profit_margin
# Out:
#         original_title  profit_margin
# 8027    Amityville 3-D            inf
# 9566  Running on Empty            inf
# 1556              Adam            inf
# 1559      Die PÃ¤pstin            inf
# 7673          Gruz 200            inf

# %% [markdown]
# Q8: What are the most profitable genres?

# %%
# Grouping by genre and calculating the mean profit
genre_profit = df.groupby('genres')['profit'].value_counts(normalize=True).unstack().fillna(0)
genre_profit

# Visualizing the results
genre_profit.plot(kind='bar', stacked=True, figsize=(10,6))
plt.title("Profitability by Genre", fontsize=14)
plt.xlabel("Genre", fontsize=12)
plt.ylabel("Proportion of Movies by Profit Category", fontsize=12)
plt.legend(title='Profit Category')
plt.grid(True)
plt.show()

# %% [markdown]
# Q9: Do movies with longer runtimes tend to receive higher votes?

# %%
# Plotting runtime against vote count
plt.figure(figsize=(8,6))
plt.scatter(df['runtime'], df['vote_count'], alpha=0.5)
plt.title("Runtime vs Vote Count", fontsize=14)
plt.xlabel("Runtime (minutes)", fontsize=12)
plt.ylabel("Vote Count", fontsize=12)
plt.grid(True)
plt.show()

# Correlation between runtime and vote count
df[['runtime', 'vote_count']].corr()
# Out:
#             runtime  vote_count
# runtime     1.00000     0.16315
# vote_count  0.16315     1.00000

# %% [markdown]
# Q10: Is there a correlation between budget and revenue?

# %%
# Scatter plot between budget and revenue
plt.figure(figsize=(8,5))
plt.scatter(df['budget'], df['revenue'], alpha=0.5)
plt.title("Budget vs Revenue", fontsize=14)
plt.xlabel("Budget (USD)", fontsize=12)
plt.ylabel("Revenue (USD)", fontsize=12)
plt.show()

# Correlation coefficient
correlation = df['budget'].corr(df['revenue'])
print(f"Correlation between Budget and Revenue: {correlation}")
# Out:
# Correlation between Budget and Revenue: 0.7411860290908815
